# %% [markdown]
# ![image.png](attachment:673f3be2-aea1-45c0-998a-9b543ad33317.png)![image.png](attachment:304b637b-64ac-435d-97c8-8704d3c11d99.png)

# %% [markdown]
# ![image.png](attachment:7667b67c-de1b-44cd-a324-d3da5c536daf.png)![image.png](attachment:5d91ecf1-af41-4619-8dbe-69acdab15e61.png)

# %% [markdown]
# ![image.png](attachment:cf2c2e05-0a22-4f74-9a1c-55b4ee8360ec.png)![image.png](attachment:5e1d5bad-dda1-4b8e-b376-31e43345c72b.png)

# %%
entrada = [1,2,4]
pesos = [0.1, 0.4,0.5] 
bias = 1

# %%
entrada[2]
# Out:
# 4

# %%
saida = entrada[0]*pesos[0]+entrada[1]*pesos[1]+entrada[2]*pesos[2]+bias

# %%
print(saida)
# Out:
# 3.9

# %%
neuron1 = X1*W11 + X2*W12 + X3*W13 + X4*W14 + bias1

neuron2 = X1*W21 + X2*W22 + X3*W23 + X4*W24 + bias2

neuron3 = X1*W31 + X2*W32 + X3*W33 + X4*W34 + bias3

# %%
entrada = [1, 2, 4, 3]


pesos = [[0.1, 0.3, 0.6, 0.4],
         
         [0.3, 0.7, 1, 0.2],
         
         [0.4, 0.2, 2, 0.1]]

bias = [1, 2, 0.4]

# %%
pesos1 = pesos[0]
pesos2 = pesos[1]
pesos3 = pesos[2]

# %%
saida = [entrada[0]*pesos1[0]+
         entrada[1]*pesos1[1]+
         entrada[2]*pesos1[2]+
         entrada[3]*pesos1[3]+bias[0],
         
         entrada[0]*pesos2[0]+
         entrada[1]*pesos2[1]+
         entrada[2]*pesos2[2]+
         entrada[3]*pesos2[3]+bias[1],
         
         entrada[0]*pesos3[0]+
         entrada[1]*pesos3[1]+
         entrada[2]*pesos3[2]+
         entrada[3]*pesos3[3]+bias[2]]

# %%
print(saida)
# Out:
# [5.3, 8.3, 9.500000000000002]

# %%
import numpy as np

# %%
saida = np.dot(pesos,entrada)+bias

# %%
saida
# Out:
# array([5.3, 8.3, 9.5])
